# %% [markdown]
# <a href="https://colab.research.google.com/github/JoyeBright/Multilingual_Multimodal_Universal_MT/blob/main/OpenNMT_ToyDataset_Eng_Ger.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Install OpenNMT**

# %%
# !pip install --upgrade pip
# !pip install OpenNMT-tf

# %% [markdown]
# ### **OpenNMT version**

# %%
# !onmt-main -v
# Out:
# 2021-01-22 15:49:04.535661: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# OpenNMT-tf 2.14.0

# %% [markdown]
# ### **Preparing the data**

# %%
# !wget https://s3.amazonaws.com/opennmt-trainingdata/toy-ende.tar.gz
# Out:
# --2021-01-22 15:56:11--  https://s3.amazonaws.com/opennmt-trainingdata/toy-ende.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.230.213
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.230.213|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1662081 (1.6M) [application/x-gzip]
# Saving to: ‘toy-ende.tar.gz’
#
# toy-ende.tar.gz     100%[===================>]   1.58M  --.-KB/s    in 0.06s
#
# 2021-01-22 15:56:11 (27.2 MB/s) - ‘toy-ende.tar.gz’ saved [1662081/1662081]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !wget https://s3.amazonaws.com/opennmt-trainingdata/toy-ende.tar.gz
# Out:
# --2021-01-22 15:49:10--  https://s3.amazonaws.com/opennmt-trainingdata/toy-ende.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.2.14
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.2.14|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1662081 (1.6M) [application/x-gzip]
# Saving to: ‘toy-ende.tar.gz.2’
#
# toy-ende.tar.gz.2   100%[===================>]   1.58M  --.-KB/s    in 0.06s
#
# 2021-01-22 15:49:11 (28.1 MB/s) - ‘toy-ende.tar.gz.2’ saved [1662081/1662081]

# %% [markdown]
# **Building vocabularies from training files**

# %%
# !onmt-build-vocab --size 50000 --save_vocab /content/drive/MyDrive/Multilingual_Multimodal_Unversal_MT/Eng_Ger_Trans_V1/data/src-vocab.txt /content/drive/MyDrive/Multilingual_Multimodal_Unversal_MT/Eng_Ger_Trans_V1/raw_data/src-train.txt
# !onmt-build-vocab --size 50000 --save_vocab /content/drive/MyDrive/Multilingual_Multimodal_Unversal_MT/Eng_Ger_Trans_V1/data/tgt-vocab.txt /content/drive/MyDrive/Multilingual_Multimodal_Unversal_MT/Eng_Ger_Trans_V1/raw_data/tgt-train.txt
# Out:
# 2021-01-22 16:02:25.294992: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-22 16:02:27.063746: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-22 16:02:27.064623: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-22 16:02:27.095871: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-22 16:02:27.096452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %% [markdown]
# ### **Train the model**

# %% [markdown]
# This command will start the training and evaluation loop of a Transformer model. <br>The --auto_config flag selects the best settings for this type of model.

# %%
# !onmt-main --model_type Transformer --config /content/drive/MyDrive/Multilingual_Multimodal_Unversal_MT/Eng_Ger_Trans_V1/config/data.yml --auto_config train --with_eval
# Out:
# 2021-01-22 16:28:37.624615: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-22 16:28:39.371765: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-22 16:28:39.372684: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-22 16:28:39.404054: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-22 16:28:39.404629: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %%
# !tensorboard --logdir="/content/drive/MyDrive/Multilingual_Multimodal_Unversal_MT/Eng_Ger_Trans_V1/model"
